# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import data, exposure

import os

# %%
img = imread('/content/drive/MyDrive/Preprocessed Images/3_30.jpg')
imshow(img)
print(img.shape)
# Out:
# (261, 310)

# %%
resized_img = resize(img, (100,150))
imshow(resized_img)
print(resized_img.shape)
# Out:
# (100, 150)

# %%
fd, hog_img = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True, multichannel=False)
# Out:
# <ipython-input-6-423ab6973fe9>:1: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_img = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),

# %%
fd.shape
# Out:
# (6732,)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7), sharex=True, sharey=True)

ax1.imshow(resized_img, cmap=plt.cm.gray)
ax1.set_title('Resized image')

hog_img_rescaled = exposure.rescale_intensity(hog_img, in_range=(0, 10))

ax2.imshow(hog_img_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients (HOG)')

plt.savefig("img_hog.jpg", dpi=125)

plt.show()
